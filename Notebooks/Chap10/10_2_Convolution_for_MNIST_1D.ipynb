# %% [markdown]
# <a href="https://colab.research.google.com/github/forestschao/udl/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-tkr2xqjp
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-tkr2xqjp
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=3d631926b5ecbdbbbd2492825d31894943842ade033124f4b7867b93cef0d10e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yv7odrz9/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
  nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
  nn.ReLU(),
  nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
  nn.ReLU(),
  nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
  nn.ReLU(),
  nn.Flatten(),
  nn.Linear(60, 10),
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.875045, train error 74.65,  val loss 1.894109, percent error 76.30
# Epoch     1, train loss 1.464589, train error 58.72,  val loss 1.479526, percent error 60.90
# Epoch     2, train loss 1.394414, train error 56.30,  val loss 1.411659, percent error 60.10
# Epoch     3, train loss 1.285383, train error 53.20,  val loss 1.292974, percent error 56.90
# Epoch     4, train loss 1.246628, train error 54.17,  val loss 1.282597, percent error 55.60
# Epoch     5, train loss 1.186653, train error 48.90,  val loss 1.207275, percent error 53.10
# Epoch     6, train loss 1.097730, train error 43.92,  val loss 1.119671, percent error 47.70
# Epoch     7, train loss 0.977278, train error 40.22,  val loss 1.012839, percent error 42.90
# Epoch     8, train loss 1.017224, train error 40.22,  val loss 1.061015, percent error 41.80
# Epoch     9, train loss 0.849465, train error 33.82,  val loss 0.908693, percent error 36.20
# Epoch    10, train loss 0.781733, train error 30.32,  val loss 0.857288, percent error 32.50
# Epoch    11, train loss 0.628332, train error 23.75,  val loss 0.701441, percent error 26.90
# Epoch    12, train loss 0.611130, train error 23.72,  val loss 0.685147, percent error 27.80
# Epoch    13, train loss 0.532578, train error 19.62,  val loss 0.619607, percent error 22.80
# Epoch    14, train loss 0.499836, train error 18.65,  val loss 0.603906, percent error 23.10
# Epoch    15, train loss 0.457371, train error 17.05,  val loss 0.583338, percent error 19.80
# Epoch    16, train loss 0.388411, train error 14.45,  val loss 0.545781, percent error 19.10
# Epoch    17, train loss 0.421268, train error 14.78,  val loss 0.579480, percent error 19.50
# Epoch    18, train loss 0.295202, train error 10.18,  val loss 0.465521, percent error 15.30
# Epoch    19, train loss 0.267249, train error 9.32,  val loss 0.405566, percent error 13.90
# Epoch    20, train loss 0.224252, train error 7.65,  val loss 0.412757, percent error 13.90
# Epoch    21, train loss 0.184970, train error 6.28,  val loss 0.370785, percent error 12.80
# Epoch    22, train loss 0.168933, train error 5.90,  val loss 0.346987, percent error 11.80
# Epoch    23, train loss 0.186842, train error 6.50,  val loss 0.366760, percent error 12.10
# Epoch    24, train loss 0.176409, train error 6.28,  val loss 0.378367, percent error 11.40
# Epoch    25, train loss 0.148290, train error 4.70,  val loss 0.359459, percent error 12.10
# Epoch    26, train loss 0.153322, train error 5.25,  val loss 0.356643, percent error 10.80
# Epoch    27, train loss 0.159844, train error 5.40,  val loss 0.375351, percent error 11.70
# Epoch    28, train loss 0.121097, train error 4.18,  val loss 0.331872, percent error 10.40
# Epoch    29, train loss 0.129663, train error 4.00,  val loss 0.336011, percent error 11.10
# Epoch    30, train loss 0.119228, train error 4.12,  val loss 0.365944, percent error 11.50
# Epoch    31, train loss 0.108764, train error 3.55,  val loss 0.339397, percent error 10.40
# Epoch    32, train loss 0.107426, train error 3.25,  val loss 0.356604, percent error 10.90
# Epoch    33, train loss 0.097567, train error 2.85,  val loss 0.351420, percent error 10.80
# Epoch    34, train loss 0.099490, train error 3.25,  val loss 0.365720, percent error 10.60
# Epoch    35, train loss 0.083954, train error 2.47,  val loss 0.354571, percent error 9.90
# Epoch    36, train loss 0.080457, train error 2.43,  val loss 0.351212, percent error 10.00
# Epoch    37, train loss 0.089963, train error 2.75,  val loss 0.364709, percent error 10.00
# Epoch    38, train loss 0.089487, train error 2.97,  val loss 0.398243, percent error 10.80
# Epoch    39, train loss 0.102660, train error 3.47,  val loss 0.389431, percent error 10.10
# Epoch    40, train loss 0.073202, train error 2.28,  val loss 0.373826, percent error 10.40
# Epoch    41, train loss 0.062086, train error 1.57,  val loss 0.366254, percent error 9.50
# Epoch    42, train loss 0.058517, train error 1.47,  val loss 0.357119, percent error 9.60
# Epoch    43, train loss 0.057107, train error 1.25,  val loss 0.367511, percent error 9.90
# Epoch    44, train loss 0.059445, train error 1.40,  val loss 0.364857, percent error 9.90
# Epoch    45, train loss 0.054897, train error 1.32,  val loss 0.382126, percent error 9.50
# Epoch    46, train loss 0.062961, train error 1.80,  val loss 0.395686, percent error 10.50
# Epoch    47, train loss 0.058537, train error 1.45,  val loss 0.381626, percent error 10.30
# Epoch    48, train loss 0.051456, train error 1.15,  val loss 0.388658, percent error 10.30
# Epoch    49, train loss 0.050035, train error 1.18,  val loss 0.383832, percent error 10.10
# Epoch    50, train loss 0.049592, train error 1.07,  val loss 0.398274, percent error 10.10
# Epoch    51, train loss 0.055327, train error 1.40,  val loss 0.395791, percent error 10.00
# Epoch    52, train loss 0.057607, train error 1.57,  val loss 0.400167, percent error 10.00
# Epoch    53, train loss 0.048386, train error 1.25,  val loss 0.385757, percent error 9.80
# Epoch    54, train loss 0.045009, train error 1.07,  val loss 0.400409, percent error 9.80
# Epoch    55, train loss 0.047378, train error 1.15,  val loss 0.405096, percent error 10.10
# Epoch    56, train loss 0.042706, train error 0.82,  val loss 0.412122, percent error 9.90
# Epoch    57, train loss 0.042704, train error 0.82,  val loss 0.398593, percent error 9.60
# Epoch    58, train loss 0.042934, train error 1.03,  val loss 0.406752, percent error 10.00
# Epoch    59, train loss 0.041510, train error 0.93,  val loss 0.409222, percent error 10.00
# Epoch    60, train loss 0.037634, train error 0.75,  val loss 0.412304, percent error 9.90
# Epoch    61, train loss 0.037714, train error 0.68,  val loss 0.414193, percent error 9.80
# Epoch    62, train loss 0.037203, train error 0.80,  val loss 0.414580, percent error 9.80
# Epoch    63, train loss 0.036793, train error 0.62,  val loss 0.411345, percent error 10.00
# Epoch    64, train loss 0.036258, train error 0.70,  val loss 0.412891, percent error 10.10
# Epoch    65, train loss 0.035573, train error 0.62,  val loss 0.415119, percent error 9.40
# Epoch    66, train loss 0.035706, train error 0.62,  val loss 0.413407, percent error 9.80
# Epoch    67, train loss 0.034234, train error 0.62,  val loss 0.418026, percent error 9.60
# Epoch    68, train loss 0.035883, train error 0.65,  val loss 0.419603, percent error 9.60
# Epoch    69, train loss 0.035657, train error 0.70,  val loss 0.426578, percent error 9.70
# Epoch    70, train loss 0.034198, train error 0.57,  val loss 0.428126, percent error 9.50
# Epoch    71, train loss 0.033605, train error 0.57,  val loss 0.425172, percent error 9.90
# Epoch    72, train loss 0.033010, train error 0.55,  val loss 0.422070, percent error 9.90
# Epoch    73, train loss 0.032578, train error 0.55,  val loss 0.427460, percent error 10.10
# Epoch    74, train loss 0.033038, train error 0.62,  val loss 0.421205, percent error 9.60
# Epoch    75, train loss 0.033667, train error 0.62,  val loss 0.433288, percent error 9.80
# Epoch    76, train loss 0.031245, train error 0.47,  val loss 0.429278, percent error 10.00
# Epoch    77, train loss 0.032528, train error 0.55,  val loss 0.429306, percent error 9.90
# Epoch    78, train loss 0.031896, train error 0.53,  val loss 0.428927, percent error 10.20
# Epoch    79, train loss 0.030706, train error 0.53,  val loss 0.433145, percent error 9.90
# Epoch    80, train loss 0.029871, train error 0.47,  val loss 0.430865, percent error 9.90
# Epoch    81, train loss 0.029995, train error 0.45,  val loss 0.432363, percent error 9.90
# Epoch    82, train loss 0.030192, train error 0.53,  val loss 0.435557, percent error 9.90
# Epoch    83, train loss 0.029378, train error 0.47,  val loss 0.435061, percent error 9.90
# Epoch    84, train loss 0.029151, train error 0.38,  val loss 0.433202, percent error 9.80
# Epoch    85, train loss 0.029012, train error 0.43,  val loss 0.434556, percent error 9.90
# Epoch    86, train loss 0.028911, train error 0.43,  val loss 0.433159, percent error 9.80
# Epoch    87, train loss 0.029144, train error 0.45,  val loss 0.435001, percent error 9.80
# Epoch    88, train loss 0.029285, train error 0.47,  val loss 0.440077, percent error 10.00
# Epoch    89, train loss 0.028532, train error 0.45,  val loss 0.436061, percent error 9.60
# Epoch    90, train loss 0.028657, train error 0.43,  val loss 0.436751, percent error 9.80
# Epoch    91, train loss 0.028295, train error 0.40,  val loss 0.437554, percent error 9.70
# Epoch    92, train loss 0.028046, train error 0.43,  val loss 0.437298, percent error 9.80
# Epoch    93, train loss 0.028068, train error 0.38,  val loss 0.438244, percent error 9.60
# Epoch    94, train loss 0.027864, train error 0.40,  val loss 0.439056, percent error 9.60
# Epoch    95, train loss 0.027614, train error 0.43,  val loss 0.437047, percent error 9.70
# Epoch    96, train loss 0.027475, train error 0.43,  val loss 0.440491, percent error 9.80
# Epoch    97, train loss 0.027679, train error 0.38,  val loss 0.442006, percent error 9.90
# Epoch    98, train loss 0.028021, train error 0.35,  val loss 0.439531, percent error 10.00
# Epoch    99, train loss 0.027232, train error 0.38,  val loss 0.442532, percent error 9.90
